# %%
# %matplotlib ipympl
import tifffile
from mpl_interactions import hyperslicer
import matplotlib.pyplot as plt
img = tifffile.imread('../data/181228_CDX2_9s_c48_n073.tif')
fig1, ax1 = plt.subplots()
control1 = hyperslicer(img, vmin=0, vmax=2000, play_buttons=True, play_button_pos="left")
# Out:
# VBox(children=(HBox(children=(Play(value=0, max=104), IntSlider(value=0, description='axis0', max=104, readout…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
